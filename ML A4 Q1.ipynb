# %% [markdown]
# 1. Read the provided CSV file ‘data.csv’.
# https://drive.google.com/drive/folders/1h8C3mLsso-R-sIOLsvoYwPLzy2fJ4IOF?usp=sharing
# 2

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import warnings # current version generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")

# %%
data= pd.read_csv("/content/ml assign 4/data.csv")
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# 2. Show the basic statistical description about the data.

# %%
data.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %% [markdown]
# 3. Check if the data has null values.

# %%
df = pd.DataFrame(data)

# %%
data.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df = pd.DataFrame(data)
mean_value=df['Calories'].mean()
df['Calories']=df['Calories'].fillna(value=mean_value, inplace=False)
print('Updated Dataframe:')
df
# Out:
# Updated Dataframe:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %% [markdown]
# 4. Select at least two columns and aggregate the data using: min, max, count, mean.

# %%
# using groupby function with aggregation
# to get mean, min and max values
result = df.groupby('Duration').agg({'Maxpulse': ['mean', 'min', 'max']})

print("Mean, min, and max values of Maxpulse grouped by Duration")
print(result)
# Out:
# Mean, min, and max values of Maxpulse grouped by Duration
#             Maxpulse
#                 mean  min  max
# Duration
# 15        119.500000  100  139
# 20        146.000000  107  172
# 25        168.000000  168  168
# 30        137.000000  107  182
# 45        133.228571  103  175
# 60        132.860759  101  170
# 75        150.000000  150  150
# 80        146.000000  146  146
# 90        116.375000  100  127
# 120       139.000000  130  157
# 150       130.250000  127  135
# 160       136.000000  135  137
# 180       125.666667  120  130
# 210       172.000000  160  184
# 270       131.000000  131  131
# 300       143.000000  143  143

# %% [markdown]
# 5. Filter the dataframe to select the rows with calories values between 500 and 1000.

# %%
df1 = df[(df['Calories']<1000) & (df['Calories']>500)] 
df1
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %% [markdown]
# 6. Filter the dataframe to select the rows with calories values > 500 and pulse < 100.

# %%
df2= df[(df['Calories']>500) & (df['Pulse']<100)]
df2
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %% [markdown]
# 7. Create a new “df_modified” dataframe that contains all the columns from df except for “Maxpulse”.

# %%
df_modified=df.drop(columns=['Maxpulse'])
df_modified
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %% [markdown]
# 8. Delete the “Maxpulse” column from the main df dataframe

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df=df.drop(columns="Maxpulse")
df
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %% [markdown]
# 9. Convert the datatype of Calories column to int datatype

# %%
df['Calories'] = df['Calories'].astype('int')
df
# Out:
#      Duration  Pulse  Calories
# 0          60    110       409
# 1          60    117       479
# 2          60    103       340
# 3          45    109       282
# 4          45    117       406
# ..        ...    ...       ...
# 164        60    105       290
# 165        60    110       300
# 166        60    115       310
# 167        75    120       320
# 168        75    125       330
#
# [169 rows x 3 columns]

# %% [markdown]
# 10. Using pandas create a scatter plot for the two columns (Duration and Calories).

# %%
df.plot.scatter(x='Duration', y='Calories')
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>
